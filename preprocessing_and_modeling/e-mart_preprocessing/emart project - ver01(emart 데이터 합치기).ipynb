# %%
import pandas as pd

# %%
emart = pd.read_excel("../데이터/이마트 데이터.xlsx",usecols="A:N")
emart
# Out:
#           지역   지점명                                    주소         위도  \
# 0      서울특별시  청계천점            대한민국 서울특별시 중구 황학동 청계천로 400  37.571015
# 1        NaN   용산점       대한민국 서울특별시 용산구 한강로3가 한강대로23길 55  37.529444
# 2        NaN   창동점            대한민국 서울특별시 도봉구 창동 노해로65길 4  37.651667
# 3        NaN   미아점             대한민국 서울특별시 성북구 길음동 도봉로 17  37.610891
# 4        NaN  하월곡점               대한민국 서울특별시 성북구 하월곡동 230  37.604873
# ..       ...   ...                                   ...        ...
# 135      NaN   순천점             대한민국 전라남도 순천시 덕암동 팔마로 191  34.942448
# 136      NaN   여수점            대한민국 전라남도 여수시 광림동 좌수영로 277  34.758000
# 137  제주특별자치도  서귀포점       대한민국 제주특별자치도 서귀포시 법환동 일주동로 9209  33.248333
# 138      NaN  신제주점       대한민국 제주특별자치도 제주시 노형동 1100로 3348  33.484904
# 139      NaN   제주점  대한민국 제주특별자치도 제주시 삼도2동 탑동로 38 제주특별자치도  33.517929
#
#              경도  3km내 이마트  3km내 경쟁 대형마트  3km내 창고형 마트     부지 면적       부지 공시지가  \
# ...

# %%
emart.지역.fillna(method="pad",inplace=True)

# %%
emart["부지 공시지가"] = emart["부지 공시지가"].astype(int)

# %%
emart.loc[:,"점포형태"] = 0

# %%
emart
# Out:
#           지역   지점명                                    주소         위도  \
# 0      서울특별시  청계천점            대한민국 서울특별시 중구 황학동 청계천로 400  37.571015
# 1      서울특별시   용산점       대한민국 서울특별시 용산구 한강로3가 한강대로23길 55  37.529444
# 2      서울특별시   창동점            대한민국 서울특별시 도봉구 창동 노해로65길 4  37.651667
# 3      서울특별시   미아점             대한민국 서울특별시 성북구 길음동 도봉로 17  37.610891
# 4      서울특별시  하월곡점               대한민국 서울특별시 성북구 하월곡동 230  37.604873
# ..       ...   ...                                   ...        ...
# 135     전라남도   순천점             대한민국 전라남도 순천시 덕암동 팔마로 191  34.942448
# 136     전라남도   여수점            대한민국 전라남도 여수시 광림동 좌수영로 277  34.758000
# 137  제주특별자치도  서귀포점       대한민국 제주특별자치도 서귀포시 법환동 일주동로 9209  33.248333
# 138  제주특별자치도  신제주점       대한민국 제주특별자치도 제주시 노형동 1100로 3348  33.484904
# 139  제주특별자치도   제주점  대한민국 제주특별자치도 제주시 삼도2동 탑동로 38 제주특별자치도  33.517929
#
#              경도  3km내 이마트  3km내 경쟁 대형마트  3km내 창고형 마트     부지 면적       부지 공시지가  \
# ...

# %%
emart_tr = pd.read_excel("../데이터/이마트 트레이더스 데이터.xlsx",usecols="A:N")
emart_tr
# Out:
#        지역    지점명                          주소         위도          경도  3km내 이마트  \
# 0     수도권    구성점       경기도 용인시 기흥구 용구대로 2457  37.304958  127.105103         0
# 1     수도권    송림점            인천광역시 동구 봉수대로 82  37.483056  126.660556         0
# 2     수도권    안산점        경기도 안산시 단원구 중앙대로 397  37.331175  126.784762         0
# 3     수도권  수원신동점           경기도 수원시 영통구 삼성로 2  37.245700  127.048032         1
# 4     수도권   킨텍스점       경기도 고양시 일산서구 킨텍스로 171  37.661667  126.744167         0
# 5     수도권  SF하남점            경기도 하남시 미사대로 750  37.547474  127.224523         1
# 6     수도권    고양점       경기도 고양시 덕양구 고양대로 1955  37.646521  126.892983         0
# 7     수도권    군포점              경기도 군포시 삼성로 74  37.339771  126.934090         1
# 8     수도권    김포점            경기도 김포시 김포대로 715  37.612586  126.730652         0
# 9     수도권    부천점             경기도 부천시 옥길동 768  37.461433  126.813638         0
# 10    수도권    위례점            경기도 하남시 위례대로 200  37.480180  127.148541         1
# ...

# %%
emart_tr["부지 공시지가"] = emart_tr["부지 공시지가"].astype(int)
emart_tr.loc[:,"점포형태"] = 1

# %%
emart_tr
# Out:
#        지역    지점명                          주소         위도          경도  3km내 이마트  \
# 0     수도권    구성점       경기도 용인시 기흥구 용구대로 2457  37.304958  127.105103         0
# 1     수도권    송림점            인천광역시 동구 봉수대로 82  37.483056  126.660556         0
# 2     수도권    안산점        경기도 안산시 단원구 중앙대로 397  37.331175  126.784762         0
# 3     수도권  수원신동점           경기도 수원시 영통구 삼성로 2  37.245700  127.048032         1
# 4     수도권   킨텍스점       경기도 고양시 일산서구 킨텍스로 171  37.661667  126.744167         0
# 5     수도권  SF하남점            경기도 하남시 미사대로 750  37.547474  127.224523         1
# 6     수도권    고양점       경기도 고양시 덕양구 고양대로 1955  37.646521  126.892983         0
# 7     수도권    군포점              경기도 군포시 삼성로 74  37.339771  126.934090         1
# 8     수도권    김포점            경기도 김포시 김포대로 715  37.612586  126.730652         0
# 9     수도권    부천점             경기도 부천시 옥길동 768  37.461433  126.813638         0
# 10    수도권    위례점            경기도 하남시 위례대로 200  37.480180  127.148541         1
# ...

# %%
emart_cl = pd.read_excel("../데이터/이마트 폐점점 데이터.xlsx",usecols="A:N")
emart_cl
# Out:
#    지역       지점명                                   주소  위도  경도  3km내 이마트  \
# 0 NaN  안산점(공단점)       경기도 안산시 단원구 동산로 63 (원시동 773-9) NaN NaN         1
# 1 NaN       공항점           서울특별시 강서구 하늘길 76 (과해동 676) NaN NaN         1
# 2 NaN       장안점  서울특별시 동대문구 한천로 42 (장안동 580, 구 장안시장) NaN NaN         1
# 3 NaN       학성점         울산광역시 중구 구교로 59 (학성동 349-15) NaN NaN         1
# 4 NaN       시지점        대구광역시 수성구 고산로 101 (신매동 566-3) NaN NaN         1
# 5 NaN       부평점         인천광역시 부평구 주부토로 241 (갈산동 171) NaN NaN         1
# 6 NaN       덕이점           고양시 일산서구 경의로 798 (덕이동 205) NaN NaN         2
# 7 NaN      서부산점             부산광역시 사상구 낙동대로 910 (감전동) NaN NaN         1
# 8 NaN       상무점               광주광역시 서구 운천로 263 (치평동) NaN NaN         1
#
#    3km내 경쟁 대형마트  3km내 창고형 마트      부지 면적       부지 공시지가  주차 시설  대중 교통  \
# 0             3            1  36023.798   76442499356    NaN    NaN
# 1             2            0  22000.000   34100000000    NaN    NaN
# ...

# %%
emart_cl.loc[:,"점포형태"] = 2

# %%
emart_cl
# Out:
#    지역       지점명                                   주소  위도  경도  3km내 이마트  \
# 0 NaN  안산점(공단점)       경기도 안산시 단원구 동산로 63 (원시동 773-9) NaN NaN         1
# 1 NaN       공항점           서울특별시 강서구 하늘길 76 (과해동 676) NaN NaN         1
# 2 NaN       장안점  서울특별시 동대문구 한천로 42 (장안동 580, 구 장안시장) NaN NaN         1
# 3 NaN       학성점         울산광역시 중구 구교로 59 (학성동 349-15) NaN NaN         1
# 4 NaN       시지점        대구광역시 수성구 고산로 101 (신매동 566-3) NaN NaN         1
# 5 NaN       부평점         인천광역시 부평구 주부토로 241 (갈산동 171) NaN NaN         1
# 6 NaN       덕이점           고양시 일산서구 경의로 798 (덕이동 205) NaN NaN         2
# 7 NaN      서부산점             부산광역시 사상구 낙동대로 910 (감전동) NaN NaN         1
# 8 NaN       상무점               광주광역시 서구 운천로 263 (치평동) NaN NaN         1
#
#    3km내 경쟁 대형마트  3km내 창고형 마트      부지 면적       부지 공시지가  주차 시설  대중 교통  \
# 0             3            1  36023.798   76442499356    NaN    NaN
# 1             2            0  22000.000   34100000000    NaN    NaN
# ...

# %%
emart_all = pd.concat([emart,emart_tr,emart_cl])

# %%
emart_all
# Out:
#        지역   지점명                               주소         위도          경도  \
# 0   서울특별시  청계천점       대한민국 서울특별시 중구 황학동 청계천로 400  37.571015  127.022913
# 1   서울특별시   용산점  대한민국 서울특별시 용산구 한강로3가 한강대로23길 55  37.529444  126.965556
# 2   서울특별시   창동점       대한민국 서울특별시 도봉구 창동 노해로65길 4  37.651667  127.046944
# 3   서울특별시   미아점        대한민국 서울특별시 성북구 길음동 도봉로 17  37.610891  127.029824
# 4   서울특별시  하월곡점          대한민국 서울특별시 성북구 하월곡동 230  37.604873  127.031185
# ..    ...   ...                              ...        ...         ...
# 4     NaN   시지점    대구광역시 수성구 고산로 101 (신매동 566-3)        NaN         NaN
# 5     NaN   부평점     인천광역시 부평구 주부토로 241 (갈산동 171)        NaN         NaN
# 6     NaN   덕이점       고양시 일산서구 경의로 798 (덕이동 205)        NaN         NaN
# 7     NaN  서부산점         부산광역시 사상구 낙동대로 910 (감전동)        NaN         NaN
# 8     NaN   상무점           광주광역시 서구 운천로 263 (치평동)        NaN         NaN
#
#     3km내 이마트  3km내 경쟁 대형마트  3km내 창고형 마트     부지 면적       부지 공시지가   주차 시설  \
# ...

# %%
emart_all = emart_all[["지점명","주소","3km내 이마트","3km내 경쟁 대형마트","3km내 창고형 마트","부지 면적","부지 공시지가",
                      "주차 시설","대중 교통","점포형태"]]

# %%
emart_all
# Out:
#      지점명                               주소  3km내 이마트  3km내 경쟁 대형마트  \
# 0   청계천점       대한민국 서울특별시 중구 황학동 청계천로 400         1             3
# 1    용산점  대한민국 서울특별시 용산구 한강로3가 한강대로23길 55         1             0
# 2    창동점       대한민국 서울특별시 도봉구 창동 노해로65길 4         1             4
# 3    미아점        대한민국 서울특별시 성북구 길음동 도봉로 17         2             2
# 4   하월곡점          대한민국 서울특별시 성북구 하월곡동 230         2             2
# ..   ...                              ...       ...           ...
# 4    시지점    대구광역시 수성구 고산로 101 (신매동 566-3)         1             2
# 5    부평점     인천광역시 부평구 주부토로 241 (갈산동 171)         1             8
# 6    덕이점       고양시 일산서구 경의로 798 (덕이동 205)         2             2
# 7   서부산점         부산광역시 사상구 낙동대로 910 (감전동)         1             2
# 8    상무점           광주광역시 서구 운천로 263 (치평동)         1             1
#
#     3km내 창고형 마트     부지 면적       부지 공시지가   주차 시설      대중 교통  점포형태
# 0             0  96410.82  861912730800  1000.0        NaN     0
# ...

# %%
emart_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   지점명           167 non-null    object
#  1   주소            167 non-null    object
#  2   3km내 이마트      167 non-null    int64
#  3   3km내 경쟁 대형마트  167 non-null    int64
#  4   3km내 창고형 마트   167 non-null    int64
#  5   부지 면적         166 non-null    float64
#  6   부지 공시지가       167 non-null    int64
#  7   주차 시설         155 non-null    float64
#  8   대중 교통         81 non-null     object
#  9   점포형태          167 non-null    int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 14.4+ KB

# %%
emart_all.corr()
# Out:
#               3km내 이마트  3km내 경쟁 대형마트  3km내 창고형 마트     부지 면적   부지 공시지가  \
# 3km내 이마트      1.000000      0.431286     0.336891  0.181294  0.466506
# 3km내 경쟁 대형마트  0.431286      1.000000     0.398570  0.112023  0.251047
# 3km내 창고형 마트   0.336891      0.398570     1.000000  0.217397  0.335626
# 부지 면적         0.181294      0.112023     0.217397  1.000000  0.678403
# 부지 공시지가       0.466506      0.251047     0.335626  0.678403  1.000000
# 주차 시설         0.081232      0.094135     0.081015  0.868800  0.528633
# 점포형태          0.237032      0.196347    -0.065661  0.216950  0.000750
#
#                  주차 시설      점포형태
# 3km내 이마트      0.081232  0.237032
# 3km내 경쟁 대형마트  0.094135  0.196347
# 3km내 창고형 마트   0.081015 -0.065661
# 부지 면적         0.868800  0.216950
# 부지 공시지가       0.528633  0.000750
# 주차 시설         1.000000  0.370498
# 점포형태          0.370498  1.000000

# %%
emart_all.reset_index(drop=True,inplace=True)

# %%
emart_all
# Out:
#       지점명                               주소  3km내 이마트  3km내 경쟁 대형마트  \
# 0    청계천점       대한민국 서울특별시 중구 황학동 청계천로 400         1             3
# 1     용산점  대한민국 서울특별시 용산구 한강로3가 한강대로23길 55         1             0
# 2     창동점       대한민국 서울특별시 도봉구 창동 노해로65길 4         1             4
# 3     미아점        대한민국 서울특별시 성북구 길음동 도봉로 17         2             2
# 4    하월곡점          대한민국 서울특별시 성북구 하월곡동 230         2             2
# ..    ...                              ...       ...           ...
# 162   시지점    대구광역시 수성구 고산로 101 (신매동 566-3)         1             2
# 163   부평점     인천광역시 부평구 주부토로 241 (갈산동 171)         1             8
# 164   덕이점       고양시 일산서구 경의로 798 (덕이동 205)         2             2
# 165  서부산점         부산광역시 사상구 낙동대로 910 (감전동)         1             2
# 166   상무점           광주광역시 서구 운천로 263 (치평동)         1             1
#
#      3km내 창고형 마트     부지 면적       부지 공시지가   주차 시설      대중 교통  점포형태
# 0              0  96410.82  861912730800  1000.0        NaN     0
# ...

# %%
emart_all.to_excel("../데이터/이마트 총합 데이터.xlsx",encoding="cp949",index=False)
