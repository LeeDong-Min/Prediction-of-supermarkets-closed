# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
sns.set(style='darkgrid')


rc('font', family='AppleGothic')
matplotlib.rcParams['axes.unicode_minus'] = False
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
emart = pd.read_excel("./prototype_model.xlsx",usecols="K:N")
emart
# Out:
#      score  점포형태      주소1         주소2
# 0     2.71     1    서울특별시  서울특별시 동대문구
# 1     2.71     1    울산광역시    울산광역시 중구
# 2     2.51     0    서울특별시   서울특별시 중랑구
# 3     2.51     1    인천광역시   인천광역시 부평구
# 4     2.47     1    부산광역시   부산광역시 사상구
# ..     ...   ...      ...         ...
# 142   1.27     0      경기도     경기도 김포시
# 143   1.27     0  세종특별자치시  세종특별자치시 남면
# 144   1.25     0      경기도     경기도 성남시
# 145   1.21     0    서울특별시   서울특별시 강남구
# 146   1.14     0      경기도     경기도 화성시
#
# [147 rows x 4 columns]

# %%
#그림여러개 한번에 그리기(꼭 따로 정리해놓기)
figure, (ax1,ax2)=plt.subplots(nrows=2,ncols=1)
figure.set_size_inches(200,10)

sns.barplot(data=emart, x="주소1",y="score",ax=ax1);
sns.barplot(data=emart, x="주소2",y="score",ax=ax2);


ax1.set(ylabel="Count",title="광역시도별 score");
ax2.set(ylabel="Count",title="시구별별 score");
